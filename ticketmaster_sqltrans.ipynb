# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "Output/concerts.csv"
concert_df = pd.read_csv(csv_file)
concert_df.head()
# Out:
#                                concert_name  \
# 0                Drums Along the Waterfront
# 1                           Lady Antebellum
# 2  Chris Stapleton's All American Road Show
# 3   Queen + Adam Lambert: The Rhapsody Tour
# 4                                John Mayer
#
#                                              artists        date      time  \
# 0    ['Drums Along the Waterfront', 'Buffalo Bills']  2019-08-04  18:30:00
# 1                                ['Lady Antebellum']  2019-08-03  20:00:00
# 2  ['Chris Stapleton', 'Margo Price', 'The Marcus...  2019-07-27  19:00:00
# 3  ['Queen + Adam Lambert', 'Queen', 'Adam Lambert']  2019-08-06  20:00:00
# 4                                     ['John Mayer']  2019-07-26  19:30:00
#
#            city state  price_min  price_max
# 0  Orchard Park    NY      29.00      29.00
# 1        Verona    NY      49.00      49.00
# 2   Canandaigua    NY      34.75      34.75
# 3      New York    NY      60.00      60.00
# 4      New York    NY      59.00      59.00

# %%
concert_df['artists']=concert_df['artists'].str.strip('[]').astype(str)
concert_df['artists']=concert_df['artists'].str.strip("'").astype(str)

# %%
concert_df.head()
# Out:
#                                concert_name  \
# 0                Drums Along the Waterfront
# 1                           Lady Antebellum
# 2  Chris Stapleton's All American Road Show
# 3   Queen + Adam Lambert: The Rhapsody Tour
# 4                                John Mayer
#
#                                              artists        date      time  \
# 0        Drums Along the Waterfront', 'Buffalo Bills  2019-08-04  18:30:00
# 1                                    Lady Antebellum  2019-08-03  20:00:00
# 2  Chris Stapleton', 'Margo Price', 'The Marcus K...  2019-07-27  19:00:00
# 3      Queen + Adam Lambert', 'Queen', 'Adam Lambert  2019-08-06  20:00:00
# 4                                         John Mayer  2019-07-26  19:30:00
#
#            city state  price_min  price_max
# 0  Orchard Park    NY      29.00      29.00
# 1        Verona    NY      49.00      49.00
# 2   Canandaigua    NY      34.75      34.75
# 3      New York    NY      60.00      60.00
# 4      New York    NY      59.00      59.00

# %%
rds_connection_string = "postgres:skim0829@localhost:5432/projectETL"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
concert_df.to_sql(name='ticketmaster', con=engine, if_exists='append', index=True)
